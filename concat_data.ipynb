# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiabet/Project_Market/blob/master/concat_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

folder_path = '/content/drive/MyDrive/강이지_옷'
tsv_files = [file for file in os.listdir(folder_path) if file.endswith('.tsv')]

combined_data = pd.concat([pd.read_csv(os.path.join(folder_path, file), sep='\t') for file in tsv_files], ignore_index=True)

combined_data.to_csv('강아지옷.tsv', sep='\t', index=False)

# %%
pd.read_csv("강아지옷.tsv", sep = '\t')
# Out:
#            user_id  score       date  \
# 0           ur****      4  23.03.20.
# 1        blac*****      5  23.02.05.
# 2       minw******      5  22.12.12.
# 3        blac*****      5  23.02.05.
# 4       dush******      5  22.12.10.
# ...            ...    ...        ...
# 128279  megi******      5  22.06.28.
# 128280  megi******      5  22.06.24.
# 128281  megi******      4  22.06.24.
# 128282      es****      3  22.07.10.
# 128283  megi******      5  22.06.23.
#
#                                                    review  is_month  \
# 0                                           군더더기 없어요 괜찮아요     False
# 1                                            촉감이 좋아서 잘입어요      True
# 2       흰색 겉옷과 같이 입히려고 샀는데 전에 이곳에서 흰색도 샀었더라구요-\n흰색은 가디...     False
# 3                                             좋아요~~~~~~~~      True
# 4                                        색상도 이쁘고 신축성도 좋네요     False
# ...                                                   ...       ...
# ...
